# %%
import pandas as pd

df = pd.read_csv("test.csv")
a = df["ID"].unique()
df1 = pd.read_csv("behavior_clean.csv")
df2 = df1[df1["ID"].isin(a)]
df2.to_csv("behavior_clean_test.csv", index=False)

# %%
df3 = df2[["ID", "Mobil03", "Mobil04", "Mobil05", "Mobil06", "Mobil07", "Mobil08", "Mobil09", "Mobil13", "Mobil14", "Mobil15", "Mobil16", "Mobil17", "Mobil18", "Mobil19", "Mobil20", "Mobil24", "Mobil26"]]
df3.to_csv("behavior_clean_test.csv", index=False)

# %%
# xoá hàng có -1 ở bất kỳ cột nào
df3 = df3[df3 != -1]
df3.to_csv("behavior_clean_test.csv", index=False)
